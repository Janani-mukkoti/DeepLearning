# %%
import requests
import json
import torch
import torch.nn as nn
import os
from tqdm import tqdm
from transformers import BertModel, BertTokenizerFast, AdamW

from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ExponentialLR
import matplotlib.pyplot as plt
#check CUDA availability
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)

num_of_questions = 0
num_of_possible = 0
num_of_impossible = 0

def get_data(path): 
    
    with open(path, 'rb') as f:
        raw_data = json.load(f)
    contexts = []
    questions = []
    answers = []
    num_q = 0
    num_pos = 0
    num_imp = 0
    for group in raw_data['data']:
        for paragraph in group['paragraphs']:
            context = paragraph['context']
            for qa in paragraph['qas']:
                question       = qa['question']
                num_q  = num_q+1
                for answer in qa['answers']:
                    contexts.append(context.lower())
                    questions.append(question.lower())
                    answers.append(answer)
    return num_q, num_pos, num_imp, contexts, questions, answers

num_q, num_pos, num_imp, train_contexts, train_questions, train_answers = get_data('spoken_train-v1.1.json')
num_of_questions  = num_q
num_of_possible = num_pos
num_of_impossible  = num_imp

num_q, num_pos, num_imp, valid_contexts, valid_questions, valid_answers = get_data('spoken_test-v1.1.json')
print(len(valid_contexts))
print(len(valid_questions))
print(len(valid_answers))
def add_answer_at_end(answers, contexts):
    for answer, context in zip(answers, contexts):
        answer['text'] = answer['text'].lower()
        answer['answer_end'] = answer['answer_start'] + len(answer['text'])

add_answer_at_end(train_answers, train_contexts)
add_answer_at_end(valid_answers, valid_contexts)

# token_lengths = []
# print(max(token_lengths))

# plt.hist(token_lengths,  bins=20)
# plt.ylabel('Count')
# plt.xlabel('Length')
# plt.title('Distribution of the Context Lengths');
# token_lengths2 = []

# for txt in train_questions:
#     txt = txt.strip() 
#     token_lengths2.append(len(txt.split(' ')))
    
# for txt in train_contexts:
#     txt = txt.strip()
#     token_lengths.append(len(txt.split(' ')))
# print(max(token_lengths2))
# print(len(token_lengths2))

# plt.hist(token_lengths2,  bins=20)
# plt.ylabel('Count')
# plt.xlabel('Length')
# plt.title('Distribution of Question Lengths. ');

token_lengths = []

# Populate token_lengths with context lengths
for txt in train_contexts:
    txt = txt.strip()
    token_lengths.append(len(txt.split(' ')))

print("Max context length:", max(token_lengths))

plt.hist(token_lengths, bins=20)
plt.ylabel('Count')
plt.xlabel('Length')
plt.title('Distribution of the Context Lengths');

token_lengths2 = []
# Populate token_lengths2 with question lengths
for txt in train_questions:
    txt = txt.strip() 
    token_lengths2.append(len(txt.split(' ')))

print("Max question length:", max(token_lengths2))
print("Number of question lengths recorded:", len(token_lengths2))

plt.hist(token_lengths2, bins=20)
plt.ylabel('Count')
plt.xlabel('Length')
plt.title('Distribution of Question Lengths.');


MAX_LENGTH = 250
MODEL_PATH = "bert-base-uncased"

print(train_questions[0:2])
print(train_contexts[0:2])

tokenizerFast = BertTokenizerFast.from_pretrained(MODEL_PATH)
train_encodings_fast = tokenizerFast(train_questions, train_contexts,  max_length = MAX_LENGTH, truncation=True, padding=True)
valid_encodings_fast = tokenizerFast(valid_questions,valid_contexts,  max_length = MAX_LENGTH, truncation=True, padding=True)
type(train_encodings_fast)
print(train_encodings_fast.keys())
print(valid_encodings_fast.keys())

print(len(train_encodings_fast['input_ids']))
print(len(train_encodings_fast['input_ids'][0]))

def return_Answer_startandend_train(idx):
    return_start = 0
    return_end = 0
    answer_encoding_fast = tokenizerFast(train_answers[idx]['text'],  max_length = MAX_LENGTH, truncation=True, padding=True)
    for a in range( len(train_encodings_fast['input_ids'][idx]) -  len(answer_encoding_fast['input_ids']) ): 
        match = True
        for i in range(1,len(answer_encoding_fast['input_ids']) - 1):
            if (answer_encoding_fast['input_ids'][i] != train_encodings_fast['input_ids'][idx][a + i]):
                match = False
                break
            if match:
                return_start = a+1
                return_end = a+i+1
                break
    return(return_start, return_end)

start_positions = []
end_positions = []
counter = 0
for t in range(len(train_encodings_fast['input_ids'])):
    s,e = return_Answer_startandend_train(t)
    start_positions.append(s)
    end_positions.append(e)
    if s==0:
        counter = counter + 1
train_encodings_fast.update({'start_positions': start_positions, 'end_positions': end_positions})
print(counter)

def return_answer_startend_valid(idx):
    return_start = 0
    return_end = 0
    answer_encoding_fast = tokenizerFast(valid_answers[idx]['text'],  max_length = MAX_LENGTH, truncation=True, padding=True)
    for a in range( len(valid_encodings_fast['input_ids'][idx])  -  len(answer_encoding_fast['input_ids'])   ): 
        match = True
        for i in range(1,len(answer_encoding_fast['input_ids']) - 1):
            if (answer_encoding_fast['input_ids'][i] != valid_encodings_fast['input_ids'][idx][a + i]):
                match = False
                break
            if match:
                return_start = a+1
                return_end = a+i+1
                break
    return(return_start, return_end)

start_positions = []
end_positions = []
counter = 0
for h in range(len(valid_encodings_fast['input_ids']) ):
   
    s, e = return_answer_startend_valid(h)
    start_positions.append(s)
    end_positions.append(e)
    if s==0:
        counter = counter + 1

valid_encodings_fast.update({'start_positions': start_positions, 'end_positions': end_positions})
print(counter)

class InputDataset(Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    def __getitem__(self, i):
        return {
            'input_ids': torch.tensor(self.encodings['input_ids'][i]),
            'token_type_ids': torch.tensor(self.encodings['token_type_ids'][i]),
            'attention_mask': torch.tensor(self.encodings['attention_mask'][i]),
            'start_positions': torch.tensor(self.encodings['start_positions'][i]),
            'end_positions': torch.tensor(self.encodings['end_positions'][i])
        }
    def __len__(self):
        return len(self.encodings['input_ids'])

train_dataset = InputDataset(train_encodings_fast)
valid_dataset = InputDataset(valid_encodings_fast)

train_data_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
valid_data_loader = DataLoader(valid_dataset, batch_size=1)

bert_model = BertModel.from_pretrained(MODEL_PATH)  #MODEL_PATH = "bert-base-uncased"

class QAModel(nn.Module):
    def __init__(self):
        super(QAModel, self).__init__()
        self.bert = bert_model
        self.drop_out = nn.Dropout(0.1)
        self.l1 = nn.Linear(768 * 2, 768 * 2)
        self.l2 = nn.Linear(768 * 2, 2)
        self.linear_relu_stack = nn.Sequential(
            self.drop_out,
            self.l1,
            nn.LeakyReLU(),
            self.l2 
        )
        
    def forward(self, input_ids, attention_mask, token_type_ids):
        model_output = self.bert(input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids, output_hidden_states=True)
        hidden_states = model_output[2]
        out = torch.cat((hidden_states[-1], hidden_states[-3]), dim=-1)  
        logits = self.linear_relu_stack(out)
        start_logits, end_logits = logits.split(1, dim=-1)
        start_logits = start_logits.squeeze(-1)
        end_logits = end_logits.squeeze(-1)

        return start_logits, end_logits

model = QAModel()


def loss_function(start_logits, end_logits, start_positions, end_positions):
    loss_fct = nn.CrossEntropyLoss()
    start_loss = loss_fct(start_logits, start_positions)
    end_loss = loss_fct(end_logits, end_positions)
    total_loss = (start_loss + end_loss)/2
    return total_loss

def focal_loss_function(start_logits, end_logits, start_positions, end_positions, gamma):
    smax = nn.Softmax(dim=1)
    probs_start = smax(start_logits)
    inv_probs_start = 1 - probs_start
    probs_end = smax(end_logits)
    inv_probs_end = 1 - probs_end
    lsmax = nn.LogSoftmax(dim=1)
    log_probs_start = lsmax(start_logits)
    log_probs_end = lsmax(end_logits)
    
    nll = nn.NLLLoss()
    
    fl_start = nll(torch.pow(inv_probs_start, gamma)* log_probs_start, start_positions)
    fl_end = nll(torch.pow(inv_probs_end, gamma)*log_probs_end, end_positions)
    return ((fl_start + fl_end)/2)

optim = AdamW(model.parameters(), lr=2e-5, weight_decay=2e-2)
scheduler = ExponentialLR(optim, gamma=0.9)
total_acc = []
total_loss = []

def train_epoch(model, dataloader, epoch):
    model = model.train()
    losses = []
    acc = []
    counter = 0
    batch_tracker = 0
    for batch in tqdm(dataloader, desc = 'Running Epoch '):
        optim.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        token_type_ids = batch['token_type_ids'].to(device)
        start_positions = batch['start_positions'].to(device)
        end_positions = batch['end_positions'].to(device)
        out_start, out_end = model(input_ids=input_ids, 
                attention_mask=attention_mask,
                token_type_ids=token_type_ids)
        
        loss = focal_loss_function(out_start, out_end, start_positions, end_positions,1) 
        losses.append(loss.item())
        loss.backward()
        optim.step()
        
        start_predictor = torch.argmax(out_start, dim=1)
        end_pred = torch.argmax(out_end, dim=1)
            
        acc.append(((start_predictor == start_positions).sum()/len(start_predictor)).item())
        acc.append(((end_pred == end_positions).sum()/len(end_pred)).item())
       
        batch_tracker = batch_tracker + 1
        if batch_tracker==250 and epoch==1:
            total_acc.append(sum(acc)/len(acc))
            loss_avg = sum(losses)/len(losses)
            total_loss.append(loss_avg)
            batch_tracker = 0
    scheduler.step()
    ret_acc = sum(acc)/len(acc)
    ret_loss = sum(losses)/len(losses)
    return(ret_acc, ret_loss)

def evaluate_model(model, dataloader):
    model = model.eval()
    losses = []
    acc = []
    counter = 0
    answer_list=[]
    with torch.no_grad():
        for batch in tqdm(dataloader, desc = 'Running the Evaluation'):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            token_type_ids = batch['token_type_ids'].to(device)
            start_true = batch['start_positions'].to(device)
            end_true = batch['end_positions'].to(device)
            
            out_start, out_end = model(input_ids=input_ids, attention_mask=attention_mask,token_type_ids=token_type_ids)
            print("out_start",out_start.shape)
            start_predictor = torch.argmax(out_start)
            end_pred = torch.argmax(out_end)
            answer = tokenizerFast.convert_tokens_to_string(tokenizerFast.convert_ids_to_tokens(input_ids[0][start_predictor:end_pred]))
            tanswer = tokenizerFast.convert_tokens_to_string(tokenizerFast.convert_ids_to_tokens(input_ids[0][start_true[0]:end_true[0]]))
            answer_list.append([answer,tanswer])
        
    return answer_list

from evaluate import load
wer = load("wer")
EPOCHS = 3
model.to(device)
wer_list=[]
for epoch in range(EPOCHS):
    train_acc, train_loss = train_epoch(model, train_data_loader, epoch+1)
    print(f"Train Accuracy: {train_acc}      Train Loss: {train_loss}")
    answer_list = evaluate_model(model, valid_data_loader)
    pred_answers=[]
    true_answers=[]
    for i in range(len(answer_list)):
        if(len(answer_list[i][0])==0):
            answer_list[i][0]="$"
        if(len(answer_list[i][1])==0):
            answer_list[i][1]="$"
        pred_answers.append(answer_list[i][0])
        true_answers.append(answer_list[i][1])
    wer_score = wer.compute(predictions=pred_answers, references=true_answers)
    wer_list.append(wer_score)
print(wer_list)

tokens = tokenizerFast.tokenize("This is a sentence.")
print(tokens)
output = tokenizerFast.convert_tokens_to_string(tokens)
print(output)
# Out:
# cuda
# 15875
# 15875
# 15875
# Max context length: 789
# Max question length: 34
# Number of question lengths recorded: 37111
# ['what is in front of the notre dame main building?', 'the basilica of the sacred heart at notre dame is beside to which structure?']
# ['architecturally the school has a catholic character. atop the main building school dome is the golden statue of the virgin mary. immediately in front of the main building in facing it is a copper statue of christ with arms appraised with the legend and the bad meow names. next to the main building is the basilica of the sacred heart. immediately behind the basilica is the grotto im mary in place of prayer and reflection. it is a replica of the grotto at lourdes france where the virgin mary reputedly appeared to st bernadette still burning eighteen fifty eight. at the end of the main drive and in a direct line that connects through three statues in the gold dome is as simple modern stone statue of mary.', 'architecturally the school has a catholic character. atop the main building school dome is the golden statue of the virgin mary. immediately in front of the main building in facing it is a copper statue of christ with arms appraised with the legend and the bad meow names. next to the main building is the basilica of the sacred heart. immediately behind the basilica is the grotto im mary in place of prayer and reflection. it is a replica of the grotto at lourdes france where the virgin mary reputedly appeared to st bernadette still burning eighteen fifty eight. at the end of the main drive and in a direct line that connects through three statues in the gold dome is as simple modern stone statue of mary.']
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# dict_keys(['input_ids', 'token_type_ids', 'attention_mask'])
# 37111
# 250
# 478
# 236
# /home/jmukkot/.local/lib/python3.11/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Running Epoch : 100%|██████████| 2320/2320 [22:37<00:00,  1.71it/s]
# Train Accuracy: 0.4135160098623099      Train Loss: 2.1466613772100414
# Running the Evaluation:   0%|          | 6/15875 [00:00<05:15, 50.26it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   0%|          | 18/15875 [00:00<05:10, 51.03it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   0%|          | 30/15875 [00:00<05:10, 51.08it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   0%|          | 42/15875 [00:00<05:09, 51.08it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   0%|          | 48/15875 [00:00<05:10, 51.00it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   0%|          | 54/15875 [00:01<05:10, 51.01it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   0%|          | 60/15875 [00:01<05:10, 50.99it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   0%|          | 72/15875 [00:01<05:09, 51.01it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 84/15875 [00:01<05:09, 51.03it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 96/15875 [00:01<05:09, 51.04it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 108/15875 [00:02<05:09, 51.02it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 114/15875 [00:02<05:08, 51.05it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 120/15875 [00:02<05:08, 51.02it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 126/15875 [00:02<05:08, 51.01it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 138/15875 [00:02<05:08, 50.98it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 150/15875 [00:02<05:08, 51.05it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 162/15875 [00:03<05:07, 51.07it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 174/15875 [00:03<05:07, 51.05it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 180/15875 [00:03<05:07, 51.03it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 186/15875 [00:03<05:07, 50.94it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|          | 192/15875 [00:03<05:08, 50.90it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|▏         | 204/15875 [00:04<05:08, 50.82it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|▏         | 216/15875 [00:04<05:07, 50.89it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   1%|▏         | 228/15875 [00:04<05:07, 50.96it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 240/15875 [00:04<05:07, 50.82it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 246/15875 [00:04<05:07, 50.84it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 252/15875 [00:04<05:08, 50.66it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 258/15875 [00:05<05:08, 50.64it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 270/15875 [00:05<05:07, 50.76it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 282/15875 [00:05<05:06, 50.84it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 294/15875 [00:05<05:08, 50.49it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 306/15875 [00:06<05:09, 50.26it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 312/15875 [00:06<05:08, 50.44it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 318/15875 [00:06<05:07, 50.61it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 324/15875 [00:06<05:07, 50.58it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 336/15875 [00:06<05:05, 50.84it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 348/15875 [00:06<05:03, 51.15it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 360/15875 [00:07<05:02, 51.31it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 372/15875 [00:07<05:02, 51.21it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 378/15875 [00:07<05:03, 51.06it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 384/15875 [00:07<05:03, 50.97it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   2%|▏         | 390/15875 [00:07<05:04, 50.90it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 402/15875 [00:07<05:04, 50.78it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 414/15875 [00:08<05:05, 50.69it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 426/15875 [00:08<05:06, 50.46it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 438/15875 [00:08<05:05, 50.57it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 444/15875 [00:08<05:05, 50.54it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 450/15875 [00:08<05:06, 50.31it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 456/15875 [00:08<05:07, 50.19it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 468/15875 [00:09<05:04, 50.55it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 480/15875 [00:09<05:03, 50.77it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 492/15875 [00:09<05:02, 50.83it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 504/15875 [00:09<05:03, 50.67it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 510/15875 [00:10<05:02, 50.75it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 516/15875 [00:10<05:02, 50.71it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 522/15875 [00:10<05:03, 50.58it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 534/15875 [00:10<05:05, 50.25it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   3%|▎         | 546/15875 [00:10<05:04, 50.28it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▎         | 558/15875 [00:10<05:05, 50.16it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▎         | 570/15875 [00:11<05:05, 50.15it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▎         | 576/15875 [00:11<05:05, 50.00it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▎         | 582/15875 [00:11<05:05, 50.09it/s]
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▎         | 588/15875 [00:11<05:05, 50.03it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▍         | 600/15875 [00:11<05:04, 50.08it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▍         | 612/15875 [00:12<05:04, 50.13it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▍         | 624/15875 [00:12<05:03, 50.28it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▍         | 636/15875 [00:12<05:03, 50.18it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:   4%|▍         | 642/15875 [00:12<05:04, 50.06it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:
/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:  99%|█████████▉| 15778/15875 [05:08<00:01, 50.75it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation:  99%|█████████▉| 15784/15875 [05:09<00:01, 50.83it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15796/15875 [05:09<00:01, 50.94it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15802/15875 [05:09<00:01, 50.92it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15808/15875 [05:09<00:01, 50.88it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15814/15875 [05:09<00:01, 50.91it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15820/15875 [05:09<00:01, 50.86it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15826/15875 [05:09<00:00, 50.79it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15832/15875 [05:10<00:00, 50.75it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15838/15875 [05:10<00:00, 50.61it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15844/15875 [05:10<00:00, 50.62it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15850/15875 [05:10<00:00, 50.56it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15862/15875 [05:10<00:00, 49.91it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|█████████▉| 15868/15875 [05:10<00:00, 50.05it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# Running the Evaluation: 100%|██████████| 15875/15875 [05:10<00:00, 51.06it/s]
# out_start torch.Size([1, 250])
# out_start torch.Size([1, 250])
# [4.678803149606299, 4.387842519685039, 3.9058897637795273]
# ['this', 'is', 'a', 'sentence', '.']
# this is a sentence.

# %%
total_start_acc = 0
total_end_acc = 0
num_batches = 0

for batch in train_data_loader:
    # Move data to device
    input_ids = batch['input_ids'].to(device)
    attention_mask = batch['attention_mask'].to(device)
    token_type_ids = batch['token_type_ids'].to(device)
    start_positions = batch['start_positions'].to(device)
    end_positions = batch['end_positions'].to(device)

    # Forward pass: obtain the model's output
    out_start, out_end = model(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)

    # Calculate accuracy for start and end position predictions
    start_predictor = torch.argmax(out_start, dim=1)
    end_predictor = torch.argmax(out_end, dim=1)

    # Calculate start and end position accuracy
    start_acc = (start_predictor == start_positions).float().mean().item()
    end_acc = (end_predictor == end_positions).float().mean().item()

    # Accumulate the accuracy for each batch
    total_start_acc += start_acc
    total_end_acc += end_acc
    num_batches += 1

# Calculate average accuracy for start and end positions
average_start_acc = total_start_acc / num_batches
average_end_acc = total_end_acc / num_batches
overall_accuracy = (average_start_acc + average_end_acc) / 2

print(f"Training Start Accuracy: {average_start_acc:.4f}, End Accuracy: {average_end_acc:.4f}, Overall Accuracy: {overall_accuracy:.4f}")
# Out:
# Training Start Accuracy: 0.8794, End Accuracy: 0.8887, Overall Accuracy: 0.8841

# %%
token_lengths = []

# Populate token_lengths with context lengths
for txt in train_contexts:
    txt = txt.strip()
    token_lengths.append(len(txt.split(' ')))

print("Max context length:", max(token_lengths))

plt.hist(token_lengths, bins=20,color='pink')
plt.ylabel('Count')
plt.xlabel('Length')
plt.title('Distribution of the Context Lengths');
# Out:
# Max context length: 789

# %%
token_lengths2 = []
# Populate token_lengths2 with question lengths
for txt in train_questions:
    txt = txt.strip() 
    token_lengths2.append(len(txt.split(' ')))

print("Max question length:", max(token_lengths2))
print("Number of question lengths recorded:", len(token_lengths2))

plt.hist(token_lengths2, bins=20,color='skyblue')
plt.ylabel('Count')
plt.xlabel('Length')
plt.title('Distribution of Question Lengths.');
# Out:
# Max question length: 34
# Number of question lengths recorded: 37111
